# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.relplot(data=iris,x="sepal_length",y="sepal_width")

# %%
sns.relplot(data=iris,x="sepal_length",y="sepal_width",hue="species",style="species")

# %%
sns.relplot(data=iris,x="sepal_length",y="sepal_width",hue="species",style="species")
sns.set_style('whitegrid')

# %%
sns.boxplot(data=iris,x="species",y="sepal_width")

# %%
sns.kdeplot(iris.loc[(iris['species']=="setosa"),'sepal_length'],color='b',label="setosa")

# %%
sns.kdeplot(iris.loc[(iris['species']=="setosa"),'sepal_length'],color='b',label="setosa")
sns.kdeplot(iris.loc[(iris['species']=="virginica"),'sepal_length'],color='r',label="virginica")
sns.kdeplot(iris.loc[(iris['species']=="versicolor"),'sepal_length'],color='g',label="versicolor")

# %%
sns.kdeplot(iris.loc[(iris['species']=="setosa"),'sepal_length'],shade='True',color='b',label="setosa")
sns.kdeplot(iris.loc[(iris['species']=="virginica"),'sepal_length'],shade='True',color='r',label="virginica")
sns.kdeplot(iris.loc[(iris['species']=="versicolor"),'sepal_length'],shade='True',color='g',label="versicolor")
sns.set_style('darkgrid')

# %%
sns.heatmap(iris.corr(),annot=True,cmap='CMRmap')

# %%
plt.scatter(iris.sepal_length,iris.sepal_width)
plt.show()

# %%
plt.bar(iris.species,iris.petal_width,color='r',width=0.5,align='center',edgecolor='g')
plt.show()

# %%
iris=np.random.randn(100)
plt.hist(iris,facecolor='b',linewidth=2,bins=10,alpha=0.6)
# Out:
# (array([ 4., 14.,  7., 13., 17., 17., 11.,  9.,  4.,  4.]),
#  array([-2.12443392, -1.69129108, -1.25814823, -0.82500539, -0.39186255,
#          0.04128029,  0.47442314,  0.90756598,  1.34070882,  1.77385166,
#          2.2069945 ]),
#  <a list of 10 Patch objects>)

# %%
labels='setosa','versicolor','virginica'
sizes=[225,245,210]
colors=['r','g','b']
explode=(0,0,0)
plt.pie(sizes,colors=colors,explode=explode,labels=labels,autopct='%1.1f%%')
plt.axis('equal')
plt.show()
